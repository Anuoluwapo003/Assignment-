# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuoluwapo003/Assignment-/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = ['Anu','Dara','Bolu','Femi']
ser=pd.Series(data)
ser
# Out:
# 0     Anu
# 1    Dara
# 2    Bolu
# 3    Femi
# dtype: object

# %%
classattendance={'Name':['Anu','Dara','Bolu','Femi'],'Attendance':[1,3,5,7],'Age':[12,36,42,23]}
df=pd.DataFrame(classattendance)
df
# Out:
#    Name  Attendance  Age
# 0   Anu           1   12
# 1  Dara           3   36
# 2  Bolu           5   42
# 3  Femi           7   23

# %%
df[['Name','Age']]
# Out:
#    Name  Age
# 0   Anu   12
# 1  Dara   36
# 2  Bolu   42
# 3  Femi   23

# %%
df['Age'].max()
# Out:
# 42

# %%
df.describe()
# Out:
#        Attendance        Age
# count    4.000000   4.000000
# mean     4.000000  28.250000
# std      2.581989  13.425722
# min      1.000000  12.000000
# 25%      2.500000  20.250000
# 50%      4.000000  29.500000
# 75%      5.500000  37.500000
# max      7.000000  42.000000

# %%
titanic = pd.read_csv("/content/Titanic-Dataset (1).csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic[['Sex','Age']]
# Out:
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
titanic.loc[[15,26,54,105,567,887],['Sex','Age']]
# Out:
#         Sex   Age
# 15   female  55.0
# 26     male   NaN
# 54     male  65.0
# 105    male  28.0
# 567  female  29.0
# 887  female  19.0

# %%
titanic.loc[[15,26,54,105,567,887]]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 26            27         0       3
# 54            55         0       1
# 105          106         0       3
# 567          568         0       3
# 887          888         1       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 15              Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 26                       Emir, Mr. Farred Chehab    male   NaN      0      0
# 54                Ostby, Mr. Engelhart Cornelius    male  65.0      0      1
# 105                        Mionoff, Mr. Stoytcho    male  28.0      0      0
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 887                 Graham, Miss. Margaret Edith  female  19.0      0      0
#
#      Ticket     Fare Cabin Embarked
# 15   248706  16.0000   NaN        S
# 26     2631   7.2250   NaN        C
# 54   113509  61.9792   B30        C
# ...
