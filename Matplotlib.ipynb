# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuoluwapo003/Assignment-/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
Year = [2014,2015,2016,2017,2017]
Temperature = [15,20,25,30,35,]
plt.plot(Year,Temperature)

# %%
plt.scatter(Year,Temperature)

# %%
plt.plot(Year,Temperature)
plt.xlabel('Year')
plt.ylabel('Temperature')
plt.title('Yearly World Temperature')
# Out:
# Text(0.5, 1.0, 'Yearly World Temperature')
